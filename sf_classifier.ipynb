# %%
from collections import defaultdict
import numpy as np, pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import json
import torch

# %%
import pandas as pd

# %%
import pickle
from sklearn.metrics import f1_score

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
with open('cor.json') as data:
    file = json.load(data)

# %%
import re

# %%
import nltk 
from nltk import word_tokenize

# %%
dialogues = [] 
for d in file[:2]:
    samples = defaultdict(dict)
    result = d['completions'][0]['result']
    texts_without_labels = d['data']['text']
    for sample in result:
        speaker = texts_without_labels[int(sample['value']['start'])]['speaker']
        samples[sample['id']]['speaker'] = speaker
        samples[sample['id']]['text'] = sample['value']['text']
        samples[sample['id']]['start'] = int(sample['value']['start'])
        if 'paragraphlabels' in sample['value']:
            samples[sample['id']]['paragraphlabels'] = sample['value']['paragraphlabels'][0]
        if 'choices' in sample['value']:
            samples[sample['id']]['choices'] = sample['value']['choices'][0]
    
    sorted_samples = sorted([(samples[sample_id]['start'], sample_id) for sample_id in samples])
    texts = []
    labels = []
    speakers = []
    for _, sample_id in sorted_samples:
        if samples[sample_id]['text'] != 'PAUSE':
            texts.append(str(samples[sample_id]['text']).replace('\n', ''))
            speakers.append(samples[sample_id]['speaker'])
            paragraph_labels = samples[sample_id].get('paragraphlabels', '')
            choices = samples[sample_id].get('choices', '')
            labels.append(paragraph_labels + '.' + choices)
    dialogues.append((texts, labels, speakers))

# %%
train_data = dialogues[1][0]
test_data = dialogues[0][0]

# %%
train_labels = dialogues[1][1]
test_labels = dialogues[0][1]

# %%
def delete_odds(list_with_lines):
    for i in range(len(list_with_lines)):        
        if 'them' in list_with_lines[i]:
            list_with_lines[i] = list_with_lines[i].replace('them', ' them ')
        if ' em ' in list_with_lines[i]:
            list_with_lines[i] = list_with_lines[i].replace(' em ', ' them ')
        if 'laugh' in list_with_lines[i]:
            list_with_lines[i] = list_with_lines[i].replace('laugh', '')
        if 'uh?' in list_with_lines[i]:
            list_with_lines[i] = list_with_lines[i].replace('uh?', '')
        if 'ʔuh' in list_with_lines[i]:
            list_with_lines[i] = list_with_lines[i].replace('ʔuh', '')
        if 'ʔ' in list_with_lines[i]:
            list_with_lines[i] = list_with_lines[i].replace('ʔ', '')
    return list_with_lines

# %%
previous_lines_sust=[]
sustains=[]
sus_tags=[]
for i in range(len(train_data)):
    if 'Sustain' in train_labels[i]:
            previous_lines_sust.append(train_data[i-1])
            sustains.append(train_data[i])
            sus_tags.append(train_labels[i])
for i in range(len(test_data)):
    if 'Sustain' in test_labels[i]:
        previous_lines_sust.append(test_data[i-1])
        sustains.append(test_data[i])
        sus_tags.append(test_labels[i])

# %%
for i in range(len(sus_tags)):
    if 'Append' in sus_tags[i]:
        sus_tags[i]=re.sub('Append','Prolong', sus_tags[i])

# %%
sustains=delete_odds(sustains)

# %%
responds=[]
previous_responds=[]
respond_tags=[]
for i in range(len(train_data)):
    if 'Answer' in train_labels[i]:
        continue
    if 'Disengage' in train_labels[i]:
        continue
    elif 'Respond' in train_labels[i]:
        responds.append(train_data[i])
        previous_responds.append(train_data[i-1])
        respond_tags.append(train_labels[i])

# %%
for i in range(len(test_data)):
    if 'Answer' in test_labels[i]:
        continue
    if 'Disengage' in test_labels[i]:
        continue
    elif 'Respond' in test_labels[i]:
        responds.append(test_data[i])
        previous_responds.append(test_data[i-1])
        respond_tags.append(test_labels[i])

# %%
def clean_responds(respond_tags):
    for i in range(len(respond_tags)):
        if 'Decline' in respond_tags[i]:
            respond_tags[i]=re.sub('Decline','Contradict',respond_tags[i])
        if 'Accept' in respond_tags[i]:
            respond_tags[i]=re.sub('Accept','Affirm',respond_tags[i])
        tag_list=respond_tags[i].split('.')[-2:]
        respond_tags[i]='.'.join(tag_list)
    return respond_tags

# %%
respond_tags=clean_responds(respond_tags)

# %%
previous_lines=[]
replies=[]
tags=[]
for i in range(len(train_data)):
    if 'Reply' in train_labels[i]:
        if '?' not in train_labels[i]:
            previous_lines.append(train_data[i-1])
            replies.append(train_data[i])
            tags.append(train_labels[i])

# %%
for i in range(len(test_data)):
    if 'Reply' in test_labels[i]:
        if '?' not in test_labels[i]:
            previous_lines.append(test_data[i-1])
            replies.append(test_data[i])
            tags.append(test_labels[i])

# %%
for i in range(len(tags)):
    tag_list = tags[i].split('.')[-2:]
    tags[i]=str('.'.join(tag_list))
    if 'Answer' in tags[i]:
        tags[i]='Response.Resolve.'

# %%
train_speakers=dialogues[1][2]
test_speakers = dialogues[0][2]

# %%
train_data = delete_odds(train_data)
test_data = delete_odds(test_data)

# %%
def get_cut_labels(labels):
    for i in range(len(labels)):
        if labels[i].startswith('Open'):
            labels[i] = 'Open.'
        if labels[i].startswith('React.Rejoinder.'):
            labels[i] = 'React.Rejoinder.'
        if labels[i].startswith('React.Respond.'):
            labels[i] = 'React.Respond.'
        if labels[i].startswith('Sustain.Continue.'):
            labels[i] = 'Sustain.Continue.'
    return labels

# %%
cut_train_labels = get_cut_labels(train_labels)

# %%
cut_test_labels = get_cut_labels(test_labels)

# %%
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained("DeepPavlov/bert-base-cased-conversational")
embed_model = AutoModel.from_pretrained("DeepPavlov/bert-base-cased-conversational")

# %%
def get_embeddings(data):
    outputs = []
    for text in data:
        with torch.no_grad():
            input_ph= tokenizer(text, padding=True, truncation=True, max_length=30,return_tensors="pt")
            output_ph = embed_model(**input_ph)
    #        train_outputs.append(output_ph.pooler_output.cpu().numpy()) 
            sentence_embedding = output_ph.last_hidden_state.mean(dim=1).cpu().numpy()
        outputs.append(sentence_embedding)
    outputs = np.concatenate(outputs)
    return outputs

# %%
all_outputs=[]
all_outputs.extend(get_embeddings(train_data))
all_outputs.extend(get_embeddings(test_data))

# %%
all_cuts=[]
all_cuts.extend(cut_train_labels)
all_cuts.extend(cut_test_labels)

# %%
path2 = 'SBC058.json'
with open(path2) as proba:
    proba=json.load(proba)
    dialogue = proba['text']
    dialogue = [i for i in dialogue if not (i['phrase'] == 'PAUSE')]
    phrases = []
    speakers=[]
    for i in range(len(dialogue)):
        phrases.append(dialogue[i]['phrase'])
        speakers.append(dialogue[i]['speaker'])

# %%
phrases = delete_odds(phrases)

# %%
from sklearn.linear_model import LogisticRegression 
model = LogisticRegression(C=0.01,class_weight='balanced')
model.fit(all_outputs,all_cuts)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
def upper_class_predict(phrase_embeddings, model):
    y_pred_sample = model.predict(phrase_embeddings)
    return y_pred_sample

# %%
#тут вся классификация
y_preds=[]
first_speaker=speakers[0]
for i in range(len(phrases)):
    test_embeddings=get_embeddings([phrases[i]])
    y_pred=''.join(list(upper_class_predict(test_embeddings, model)))
    if i==0:
        y_pred='Open.'
        if y_pred=='Open.':
            y_pred=get_open_labels(phrases[i],y_pred,nn_classifier,scaler)
        y_preds.append(y_pred)
    else:
#         y_pred=check_sustain(phrases[i],y_pred,y_preds[i-1],speakers[i], speakers[i-1])
        if y_pred=='Open.':
            y_pred=get_open_labels(phrases[i],y_pred,nn_classifier,scaler)
        if y_pred=='Sustain.Continue.':
            y_pred=check_develop(phrases[i],phrases[i-1],y_pred, y_preds[i-1],speakers[i], speakers[i-1])
            y_pred=get_label_for_sustains(phrases[i], y_pred, lr_sus)
        if '?' in phrases[i]:
            y_pred=get_label_for_question(phrases[i],y_pred,speakers[i], speakers[i-1], true_tracks, lr2,interrogative_words)
        if y_pred=='React.Respond.':
             y_pred=get_label_for_responds(phrases[i],phrases[i-1], y_pred,y_preds[i-1],speakers[i],speakers[i-1], lr_reply,lr_responds)
        if y_pred=='React.Rejoinder.':
            y_pred=get_labels_for_rejoinder(phrases[i],y_pred,y_preds[i-1],phrases[i-1], speakers[i], speakers[i-1])
        y_preds.append(y_pred)

# %%
for i in zip(speakers, phrases,y_preds):
    print(i)
# Out:
# ('STEV', " Here's nice place to put my shoes.", 'Open.Give.Fact.')
# ('SHER', ' Yeah there it is.', 'React.Respond.Reply.Agree')
# ('STEV', ' Mom look.', 'React.Respond.Support.Engage')
# ('SHER', ' Unhunh what?', 'React.Rejoinder.Track.Check')
# ('STEV', ' Look at my shoes.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' They look like the phantom stairsteppers.', 'React.Respond.Develop.Elaborate')
# ('SHER', ' Hunh.', 'React.Respond.Support.Register')
# ('STEV', ' No,no', 'React.Respond.Reply.Disagree')
# ('STEV', ' it looks like the Invisible Man.', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' It  does look like the Invisible Man.', 'React.Respond.Develop.Elaborate')
# ('SHER', ' Ohho That felt good.', 'React.Respond.Reply.Acknowledge')
# ('STEV', " Wasn't there guy called the Invisible Man ?", 'React.Rejoinder.Track.Confirm')
# ('SHER', ' Yes there was.', 'React.Respond.Reply.Affirm')
# ('STEV', ' Was he in movie ?', 'React.Rejoinder.Track.Confirm')
# ('SHER', ' Yes he was.', 'React.Respond.Reply.Affirm')
# ('STEV', ' What was it called?', 'React.Rejoinder.Track.Clarify')
# ('SHER', ' The Invisible Man.', 'React.Respond.Response.Resolve.')
# ('SHER', ' It was kind of show kinda like The Shadow was.', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' You know it was', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Actually though I think they made remake of it', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' with Chevy Chase', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' that was really lousy though.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Steven,You know what you could do that would be just really helpful ?', 'Open.Demand.Fact.')
# ('STEV', ' Say it.', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' You could take these Coke cans', 'React.Respond.Develop.Enhance')
# ('SHER', ' and put  them  in the bag full of Coke cans that are in your bedroom', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' and then we can do can squish.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' And squish em.', 'React.Respond.Develop.Extend')
# ('SHER', ' For the recycling bin.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Okay ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Tomorrow please my feet are hurting.', 'Open.Give.Fact.')
# ('SHER', ' Tomorrow ?', 'React.Rejoinder.Track.Probe')
# ('SHER', ' Well can you just put them in the bag in there for now, okay ?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' Okay.', 'React.Respond.Reply.Agree')
# ('SHER', ' Cause I gotta clean up in here', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' this place is just totally trashed', 'Sustain.Continue.Prolong.Extend')
# ('SHER', " cause I've done nothing this week but study and be sick.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', " I've got really bad dental problem or something with my mouth.", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Poor Mom.', 'Open.Attend')
# ('SHER', " Think I've got sinus infection or something.", 'Open.Give.Fact.')
# ('SHER', " Don't Steven.", 'React.Respond.Develop.Extend')
# ('STEV', ' Mmkay.', 'React.Respond.Reply.Affirm')
# ('SHER', " Please, I know it's tempting.", 'Open.Give.Fact.')
# ('SHER', " What I'd like you to do is put those cans away please.", 'Open.Give.Fact.')
# ('STEV', ' Where ?', 'React.Rejoinder.Track.Clarify')
# ('STEV', ' Oh there they are.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Yeah', 'React.Respond.Reply.Affirm')
# ('SHER', ' there they are.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' A one, a two.', 'React.Respond.Develop.Elaborate')
# ('STEV', " Let's make the statue of hamburger city.", 'React.Respond.Develop.Extend')
# ('SHER', ' Mm.', 'React.Respond.Support.Register')
# ('STEV', ' The statue of Coke.', 'React.Respond.Develop.Extend')
# ('SHER', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('STEV', ' The swinging barn.', 'React.Respond.Develop.Extend')
# ('SHER', " You're just swinging kid Steve.", 'Open.Give.Fact.')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Agree')
# ('STEV', " You don't know the half of it.", 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', " I don't know the half of it,do I?", 'React.Rejoinder.Track.Confirm')
# ('SHER', ' Yeah', 'React.Respond.Reply.Affirm')
# ('SHER', ' Oh man.', 'React.Respond.Support.Register')
# ('SHER', ' Hey Steve', 'Open.Attend')
# ('SHER', " why don't you give your iguana little bit of banana too?", 'React.Rejoinder.Re-challenge')
# ('SHER', " he'd probably really like some.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', " He'd probably really like some banana.", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Thanks for Mom.', 'React.Respond.Develop.Extend')
# ('SHER', " Oh and I think this is Robbie's shirt", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' and his HarleyDavidson scarf,right ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Hmm ?', 'React.Rejoinder.Track.Check')
# ('SHER', " Isn't that Robbie's shirt?", 'React.Rejoinder.Track.Confirm')
# ('SHER', ' and uh Harley Davidson scarf from this summer ?', 'React.Rejoinder.Track.Probe')
# ('SHER', ' I wanted to give that back to  them  tomorrow when we go over for his birthday.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' I need to get Robbie um present too.', 'React.Respond.Develop.Enhance')
# ('SHER', ' Yeah', 'React.Respond.Reply.Affirm')
# ('SHER', " what do you think he'd like to have?", 'React.Rejoinder.Track.Clarify')
# ('STEV', " I'm not sure", 'React.Respond.Reply.Disawow')
# ('STEV', " but we could go over to Toys 'R' Us.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', " it seems to me I brought the Toys 'R' Us catalog back with me.", 'React.Respond.Develop.Extend')
# ('STEV', " It's right over there.", 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' Okay.', 'React.Respond.Reply.Agree')
# ('STEV', " It's over there.", 'React.Respond.Develop.Extend')
# ('SHER', " why don't you have look at it and see if anything comes to mind?", 'React.Rejoinder.Re-challenge')
# ('SHER', ' for something you think Robbie would like to have', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' for his birthday.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Well I have some things in here for Christmas.', 'React.Respond.Develop.Enhance')
# ('SHER', ' Yeah', 'React.Respond.Reply.Affirm')
# ('SHER', ' I know you probably see things in there that you want for Christmas', 'Sustain.Continue.Prolong.Extend')
# ('SHER', " but right now we're thinking about him and his birthday.", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Okay.', 'React.Respond.Support.Register')
# ('SHER', ' And I gotta get started on this chicken pizza or if anybody actually takes me up on this and comes...', 'Sustain.Continue.Prolong.Extend')
# ('STEV', " There's coupons in here too Mom", 'React.Respond.Develop.Extend')
# ('STEV', " So, Mom there's coupons in here.", 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' so we can get some things.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Mhm', 'React.Respond.Support.Register')
# ('SHER', ' Really ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Are they good things ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('STEV', " And there's also Nickelodean free.", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' um box there.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Really?', 'React.Rejoinder.Track.Confirm')
# ('STEV', " And it's bowl with goodies and coupons.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Oh wow.', 'React.Respond.Support.Register')
# ('STEV', " And that's why I wanna get that.", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' I know something that Robbie may like ', 'React.Respond.Develop.Extend')
# ('STEV', ' Let me try to find it.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Yeah unhunh ?', 'React.Rejoinder.Track.Check')
# ('STEV', " It's Yack Pack.", 'React.Respond.Response.Resolve.')
# ('SHER', ' Is that full of yucky stuff ?', 'React.Rejoinder.Track.Confirm')
# ('SHER', ' Or what?', 'React.Rejoinder.Track.Clarify')
# ('STEV', ' No.', 'React.Respond.Reply.Disagree')
# ('SHER', ' Are you sure ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' No.', 'React.Respond.Reply.Disagree')
# ('STEV', " It's kinda like tape recorder.", 'React.Respond.Develop.Enhance')
# ('SHER', ' Oh, It is.', 'React.Respond.Reply.Agree')
# ('STEV', ' See you um', 'Open.Give.Fact.')
# ('STEV', ' Like you tape record your dad saying clean your room.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Unhunh.', 'React.Respond.Support.Register')
# ('STEV', " And then there's this girl on TV", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' and you play it', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' and it.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', " And the girl says: 'clean your room.'", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' So is it kinda like one of those Talkboys', 'React.Respond.Develop.Extend')
# ('SHER', ' like that was in.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' What do you call it?', 'React.Rejoinder.Track.Clarify')
# ('SHER', ' what was that?', 'React.Rejoinder.Track.Clarify')
# ('SHER', ' How much would something like that cost?', 'React.Rejoinder.Track.Clarify')
# ('STEV', ' Um', 'React.Respond.Reply.Affirm')
# ('STEV', ' let me look for it.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', " It's in here cause I circled it.", 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' Okay it costs nine ninety nine.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Are you sure ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', " Yeah, that's it.", 'React.Respond.Reply.Affirm')
# ('SHER', ' Well we could probably afford that', 'React.Respond.Develop.Enhance')
# ('SHER', ' hunh ?', 'React.Rejoinder.Track.Check')
# ('STEV', ' Oh wait minute.', 'React.Respond.Reply.Affirm')
# ('STEV', ' I think it says twelve ninety nine.', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' Twelve ninety nine ?', 'React.Rejoinder.Track.Probe')
# ('STEV', ' Thirteen.', 'React.Respond.Reply.Affirm')
# ('STEV', ' Come over here and look.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' And...', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Alright.', 'React.Respond.Support.Register')
# ('SHER', ' Hang on just second honey.', 'React.Respond.Develop.Extend')
# ('STEV', ' I think it says twelve ninety nine', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' and then right here it says Yack Pack', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' nine ninety nine.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Ah.', 'React.Respond.Support.Register')
# ('STEV', ' Maybe it means Yack Pack one and this is Yack Pack two.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Yack Pack two.', 'React.Respond.Develop.Extend')
# ('STEV', ' Two.', 'React.Respond.Support.Register')
# ('SHER', ' Unhunh.', 'React.Respond.Support.Register')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Hunh.', 'React.Respond.Support.Register')
# ('STEV', ' Should we get it ?', 'React.Rejoinder.Re-challenge')
# ('SHER', " I don't know.", 'React.Respond.Reply.Disawow')
# ('SHER', " Why don't we go to Toys 'R' Us tomorrow and we'll look for it?", 'Open.Demand.Fact.')
# ('SHER', ' Research it.', 'React.Respond.Develop.Extend')
# ('SHER', " We'll see", 'Open.Give.Fact.')
# ('STEV', " There's also um.", 'React.Respond.Develop.Elaborate')
# ('SHER', ' What it says they are there?', 'React.Rejoinder.Track.Clarify')
# ('STEV', ' Yeah, it does.', 'React.Respond.Reply.Affirm')
# ('STEV', " And there's...", 'Sustain.Continue.Prolong.Extend')
# ('SHER', " Cause I really don't know", 'React.Respond.Reply.Disawow')
# ('SHER', " it's hard to tell you know", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' if I can afford it', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' unless I know exactly what the price is on it.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', " There's also some movies I want.", 'React.Respond.Develop.Enhance')
# ('SHER', ' Really?', 'React.Rejoinder.Track.Confirm')
# ('SHER', ' And what are those?', 'React.Rejoinder.Track.Clarify')
# ('STEV', ' Like Batman Forever.', 'React.Respond.Response.Resolve.')
# ('SHER', ' Mhm.', 'React.Respond.Support.Register')
# ('STEV', ' and The Santa Clause.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' With Tim Allen.', 'React.Respond.Develop.Extend')
# ('SHER', ' Who was it who was saying they were gonna buy the movie Casper the Ghost today ?', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Was that Jack ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Zach.', 'React.Respond.Reply.Affirm')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Ah.', 'React.Respond.Support.Register')
# ('STEV', ' And mom, you know what the fun?', 'Sustain.Continue.Monitor')
# ('STEV', ' the.', 'Sustain.Continue.Prolong.Elaborate')
# ('STEV', " It's kind of game", 'React.Respond.Develop.Enhance')
# ('STEV', ' except um you.', 'Sustain.Continue.Monitor')
# ('SHER', ' Unhunh.', 'React.Respond.Support.Register')
# ('STEV', ' you ask your cosmic questions', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' oja ?', 'React.Rejoinder.Track.Check')
# ('STEV', ' Oija ?', 'React.Rejoinder.Track.Check')
# ('SHER', ' Ouija.', 'React.Rejoinder.Response.Resolve')
# ('STEV', ' Ouija.', 'React.Respond.Develop.Extend')
# ('SHER', ' Yeah like Ouiji.', 'React.Respond.Reply.Affirm')
# ('SHER', ' We used to call  them  Ouija boards.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Oh god my head hurts.', 'Open.Give.Fact.')
# ('STEV', ' Did you like it ?', 'React.Rejoinder.Re-challenge')
# ('SHER', ' Oh.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Hunh ?', 'React.Rejoinder.Track.Check')
# ('STEV', ' Did you like it ?', 'React.Rejoinder.Re-challenge')
# ('SHER', ' Yeah I used to love Ouija boards when I was little girl.', 'Open.Give.Fact.')
# ('SHER', ' I thought they were really fun.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Course we always asked them questions we already knew the answer to.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Like what?', 'React.Rejoinder.Track.Clarify')
# ('STEV', ' your homework ?', 'React.Rejoinder.Track.Probe')
# ('SHER', ' Oh man.', 'React.Respond.Reply.Affirm')
# ('SHER', ' I feel like my brains are gonna to come out.', 'Sustain.Continue.Prolong.Elaborate')
# ('STEV', ' Like that ?', 'React.Rejoinder.Track.Confirm')
# ('SHER', ' Hunh ?', 'React.Rejoinder.Track.Check')
# ('STEV', " Like man my brains feel like they're gonna come out ", 'Sustain.Continue.Prolong.Extend')
# ('SHER', " Well, I've either got sinus.", 'React.Respond.Develop.Enhance')
# ('SHER', ' Really bad sinus infection', 'Sustain.Continue.Prolong.Extend')
# ('SHER', " or I've got an impacted tooth or something.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' But my head hurts all the way up my nose and my teeth hurt and', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' basically I just am mess babe.', 'Sustain.Continue.Prolong.Elaborate')
# ('STEV', " You don't know the half of it.", 'React.Respond.Develop.Elaborate')
# ('SHER', ' Mhm,Yeah.', 'React.Respond.Support.Register')
# ('STEV', ' Robbie does like remote control cars.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', 'I see lots of  them  in here.', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' Oh does he ?', 'React.Rejoinder.Track.Confirm')
# ('SHER', ' He likes those ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', " Well his Dad's into that too.", 'React.Respond.Develop.Enhance')
# ('STEV', ' But...', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', " cause he's into those HarleyDavidsons and stuff.", 'React.Respond.Develop.Extend')
# ('SHER', " Isn't he?", 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Yeah but there is something in here that...', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' Unhunh.', 'React.Respond.Support.Register')
# ('STEV', ' The Doctor Dreadful drink lab.', 'React.Respond.Develop.Extend')
# ('SHER', ' The who what ?', 'React.Rejoinder.Track.Clarify')
# ('STEV', ' The Doctor Dreadful drink lab.', 'React.Rejoinder.Response.Resolve')
# ('SHER', ' The Doctor  Dreadful drink lab.', 'React.Respond.Develop.Extend')
# ('SHER', ' Oh boy.', 'React.Respond.Support.Register')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('STEV', ' He makes some really nasty drinks that taste great.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Really ?', 'React.Rejoinder.Track.Confirm')
# ('SHER', ' This place is such mess.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Hey Steve', 'Open.Attend')
# ('SHER', ' remind me tomorrow when we go shopping', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' That I wanna get some potting soil.', 'React.Respond.Develop.Extend')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Cause I wanna put these geraniums in pot.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', " Because why they aren't dead I don't know", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' because all I do is take  them  to the brink of death all the time and', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' and somehow they manage to keep surviving me', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' and all my neglect.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' But I wanna get  them  in pot.', 'React.Respond.Develop.Extend')
# ('SHER', "Because one of  them 's gonna flower.", 'React.Respond.Develop.Extend')
# ('SHER', " It's so pretty.", 'Open.Give.Fact.')
# ('SHER', ' And if they were', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' you know', 'Sustain.Continue.Monitor')
# ('SHER', ' in pot with good soil and water', 'Sustain.Continue.Prolong.Extend')
# ('SHER', " they'd be just beautiful.", 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', " They'd be up and rolling.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' See if I can find the recipe for my Malaysian chicken pizza.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Man', 'React.Respond.Support.Register')
# ('SHER', ' I had the longest day at work today.', 'Open.Give.Fact.')
# ('SHER', ' Just took forever.', 'React.Respond.Develop.Extend')
# ('SHER', " Okay,Let's see I gotta find my recipe.", 'Open.Give.Fact.')
# ('SHER', " This'll be the tough part.", 'React.Respond.Develop.Elaborate')
# ('SHER', " Geez I'd lose my head if it wasn't sewn on.", 'Open.Give.Fact.')
# ('SHER', ' I hope nobody.', 'React.Respond.Develop.Extend')
# ('SHER', ' I almost hope nobody does show up for this thing', 'Sustain.Continue.Prolong.Extend')
# ('SHER', " cause I'm not at all ready.", 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' Now look I got the sniffles.', 'Open.Give.Fact.')
# ('SHER', ' Do you honey got cold going ?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Aw.', 'React.Respond.Support.Register')
# ('STEV', ' Look at Sneaker Mom.', 'React.Respond.Develop.Extend')
# ('SHER', " I'm sorry.", 'React.Respond.Support.Engage')
# ('STEV', ' look on his hand', 'Sustain.Continue.Prolong.Extend')
# ('STEV', " he's shedding on his hand.", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' I know he is shedding on his hands.', 'React.Respond.Develop.Enhance')
# ('SHER', " You're right.", 'React.Respond.Reply.Agree')
# ('STEV', " He's such good little old boy.", 'Open.Give.Fact.')
# ('SHER', ' He is.', 'React.Respond.Reply.Agree')
# ('SHER', ' I wanna put some grow lights in here for him', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' so we have', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' what the heck?', 'React.Rejoinder.Track.Clarify')
# ('SHER', " There we go, there's my pizza recipe", 'Sustain.Continue.Prolong.Enhance')
# ('STEV', " At least he's not sitting on his feet when I pet him now.", 'Open.Give.Fact.')
# ('SHER', ' Well I got the heat turned.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Oh Steven', 'React.Respond.Support.Register')
# ('SHER', ' that reminds me.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', " I've got the heat turned on in here", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', " so we've got gas heater in here.", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', " So every once in while it'll fire on and you'll see like flames go on or something", 'Sustain.Continue.Prolong.Extend')
# ('SHER', " don't be scared", 'Sustain.Continue.Prolong.Extend')
# ('SHER', " but don't mess with this here and this plate in your bedroom.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Steven.', 'React.Respond.Support.Register')
# ('STEV', ' Mhm ?', 'React.Rejoinder.Track.Check')
# ('SHER', " The landlord's gotta put vent over it.", 'React.Rejoinder.Response.Resolve')
# ('SHER', ' Come here', 'React.Respond.Support.Engage')
# ('SHER', ' I wanna show you.', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' Please come here.', 'React.Respond.Develop.Extend')
# ('STEV', ' Mhm ?', 'React.Rejoinder.Track.Check')
# ('SHER', " Don't touch this cause you could burn yourself.", 'React.Rejoinder.Response.Resolve')
# ('SHER', ' Okay ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' With the gas heater...', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', " Don't touch this", 'React.Respond.Develop.Enhance')
# ('SHER', " And don't mess with this uh pipe here at all cause that's where the gas goes through.", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Okay ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Mhm.', 'React.Respond.Reply.Affirm')
# ('SHER', " So with that in mind cause that's not up...", 'Sustain.Continue.Prolong.Extend')
# ('SHER', " That's not up to building code.", 'React.Respond.Develop.Extend')
# ('SHER', ' Um, the gas guy', 'React.Respond.Develop.Extend')
# ('SHER', " when he came in he told me that's not code", 'Sustain.Continue.Prolong.Extend')
# ('SHER', " and he said it wasn't that it was unsafe but we still need to be very careful about it.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Alright ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Alright Mom.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Did you hear me okay ?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Okay.', 'React.Respond.Support.Register')
# ('SHER', ' So come here', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' what do you want me to put on your pizza?', 'React.Rejoinder.Re-challenge')
# ('SHER', ' Steve. Esteban.', 'React.Respond.Support.Register')
# ('SHER', " You're gonna have pepperoni and stuff on your pizza?", 'React.Rejoinder.Re-challenge')
# ('SHER', ' or are you not hungry right now?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' I want some pepperoni.', 'Open.Give.Fact.')
# ('SHER', ' Mhm ?', 'React.Rejoinder.Track.Check')
# ('STEV', ' Some hmm.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Mhm.', 'React.Respond.Support.Register')
# ('STEV', ' cheese.', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' Okay ?', 'React.Rejoinder.Track.Confirm')
# ('SHER', ' You want mozzarella ?', 'React.Rejoinder.Re-challenge')
# ('STEV', " What's that?", 'React.Rejoinder.Track.Clarify')
# ('SHER', ' Mozzarella ?', 'React.Rejoinder.Track.Probe')
# ('SHER', " That's that white cheese that gets all stringy and melted", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' You mean the one that I kinda like um Figaro ?', 'React.Rejoinder.Re-challenge')
# ('SHER', ' Hmm.', 'React.Respond.Reply.Affirm')
# ('SHER', " I'm making Malaysian chicken pizza.", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Where are you?', 'React.Rejoinder.Track.Clarify')
# ('STEV', ' No chicken pizza.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' You want.', 'React.Respond.Develop.Extend')
# ('SHER', " No, it's wonderful", 'React.Respond.Reply.Disagree')
# ('SHER', " Steven, it's better than.", 'React.Respond.Develop.Enhance')
# ('STEV', ' I do not like chicken in my pizza.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Well.', 'React.Respond.Support.Register')
# ('SHER', " I know peanut butter seems weird to have on pizza but it's really good.", 'Sustain.Continue.Prolong.Elaborate')
# ('STEV', ' No I said...', 'React.Respond.Develop.Elaborate')
# ('SHER', ' Come here please.', 'React.Respond.Develop.Extend')
# ('STEV', ' You said chicken and...', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Yeah I know.', 'React.Respond.Reply.Acknowledge')
# ('SHER', ' Oh man', 'React.Respond.Support.Register')
# ('SHER', ' I forgot to get the Pam cooking spray.', 'Open.Give.Opinion.')
# ('SHER', ' Doggone it.', 'React.Respond.Develop.Elaborate')
# ('SHER', ' Do you need an asthma treatment ?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' No.', 'React.Respond.Reply.Disagree')
# ('STEV', ' Just got cough.', 'React.Respond.Develop.Enhance')
# ('SHER', ' Are you sure ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Yes.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Did you give Sneaker some fresh lettuce ?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Okay.', 'React.Respond.Support.Register')
# ('SHER', " I've got chicken cacciatore here too honey that I can heat up for you if you're hungry.", 'Open.Give.Fact.')
# ('SHER', ' If it takes too long for me to make the pizza.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' Okay.', 'React.Respond.Support.Register')
# ('SHER', ' Okay ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Okay.', 'React.Respond.Reply.Affirm')
# ('SHER', " I know you're probably hungry.", 'Open.Give.Fact.')
# ('SHER', ' Tell you what', 'Sustain.Continue.Monitor')
# ('SHER', " I'll make your pizza first cause yours is easy to make.", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', " And then I'll make this fancy one second.", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Okay.', 'React.Respond.Reply.Agree')
# ('SHER', " That way you won't have to wait very long to eat.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', " Cause I don't know", 'React.Respond.Reply.Disawow')
# ('SHER', " I don't know if", 'React.Respond.Develop.Extend')
# ('SHER', ' These people may not even show up.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', " You know they're kind of flaky.", 'Sustain.Continue.Prolong.Elaborate')
# ('STEV', " Think they'll ever.", 'React.Respond.Develop.Extend')
# ('STEV', " I think they'll just stay home.", 'React.Respond.Develop.Enhance')
# ('SHER', " Well I don't know.", 'React.Respond.Reply.Disawow')
# ('STEV', ' There.', 'React.Respond.Reply.Agree')
# ('STEV', ' Here it is, Mom.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' The free Nickelodean treat box.', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' Free...', 'React.Respond.Develop.Elaborate')
# ('STEV', " Bring this coupon to Toys 'R' Us and get your free Nickelodean ar treat box.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Hm.', 'React.Respond.Support.Register')
# ('STEV', ' filled with goodies and coupons.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Mmkay.', 'React.Respond.Support.Register')
# ('SHER', ' Mmkay', 'React.Respond.Develop.Enhance')
# ('SHER', " we're going to make yours", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' quick and dirty kid.', 'React.Respond.Develop.Elaborate')
# ('SHER', " Let's see where's that stuff.", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Aw man', 'React.Respond.Support.Register')
# ('SHER', ' This stuff can go over here', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' so Steve', 'React.Respond.Develop.Extend')
# ('SHER', ' you going to computer lab now at the Hemingway Learning Institute ?', 'React.Rejoinder.Re-challenge')
# ('SHER', ' Is that fun ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Hmm.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Yeah ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', " Well I never Well I didn't go last Friday because I forgot.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Oh did you ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Cause it just started huh.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Yeah.', 'React.Respond.Reply.Agree')
# ('STEV', " I'm not sure if they counted me.", 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', " Oh I don't know babe.", 'React.Respond.Reply.Disawow')
# ('SHER', ' Did your dad go to California this weekend ?', 'React.Rejoinder.Re-challenge')
# ('STEV', " He's .", 'React.Respond.Reply.Affirm')
# ('STEV', ' He just le left today before I woke up.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Oh, he left this morning ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' California ?', 'React.Rejoinder.Track.Probe')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Okay.', 'React.Respond.Support.Register')
# ('SHER', ' Steven', 'React.Respond.Develop.Extend')
# ('SHER', ' do you know how to grate cheese ?', 'React.Rejoinder.Rebound')
# ('STEV', ' Grate cheese ?', 'React.Rejoinder.Track.Probe')
# ('SHER', ' Yes.', 'React.Respond.Reply.Affirm')
# ('STEV', ' Yeah why?', 'React.Rejoinder.Track.Clarify')
# ('STEV', " You don't know how to Mom ?", 'React.Rejoinder.Track.Confirm')
# ('SHER', ' I beg your pardon ?', 'React.Rejoinder.Track.Check')
# ('STEV', " You don't know how to ?", 'React.Rejoinder.Track.Confirm')
# ('SHER', " I'm sorry", 'React.Respond.Reply.Disawow')
# ('SHER', " I can't hear you.", 'React.Respond.Develop.Extend')
# ('STEV', ' Do you?', 'React.Rejoinder.Track.Confirm')
# ('STEV', " You don't know how to ?", 'React.Rejoinder.Track.Confirm')
# ('SHER', ' No, I do know how to.', 'React.Respond.Reply.Disawow')
# ('SHER', " I'm wondering if you would like to grate some cheese to put on your pizza.", 'Open.Give.Fact.')
# ('STEV', ' Sure.', 'React.Respond.Reply.Agree')
# ('SHER', ' Or are you enjoying just looking at your catalog?', 'React.Rejoinder.Re-challenge')
# ('SHER', " You don't have to do that if you don't want to.", 'Sustain.Continue.Prolong.Extend')
# ('STEV', " I'll grate em.", 'React.Respond.Develop.Extend')
# ('STEV', ' wants to.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Okay.', 'React.Respond.Support.Register')
# ('SHER', " We're gonna need to put sauce on the uh.", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Oh boy my face hurts.', 'Open.Give.Fact.')
# ('STEV', ' thing first ?', 'React.Rejoinder.Track.Probe')
# ('SHER', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', " I've gotta...", 'Open.Give.Fact.')
# ('STEV', ' Okay', 'React.Respond.Support.Register')
# ('STEV', " I'll wait until after that.", 'React.Respond.Develop.Elaborate')
# ('SHER', " Well, putting sauce on it's real simple.", 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' All I have to do is open can', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' and dump it on.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', " It's.", 'React.Respond.Reply.Affirm')
# ('SHER', " We're doing things very simple tonight.", 'Sustain.Continue.Prolong.Elaborate')
# ('STEV', ' Mom', 'React.Respond.Support.Register')
# ('STEV', ' they have costumes in here too.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Do they have Tick costume that you wanted ?', 'React.Rejoinder.Re-challenge')
# ('STEV', " No, they don't.", 'React.Respond.Reply.Disagree')
# ('SHER', ' Hm.', 'React.Respond.Support.Register')
# ('STEV', ' They have Spider Man', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Jaws', 'React.Respond.Support.Register')
# ('STEV', ' a gargoyle', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' some ninja', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' clown and witch.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Unhunh.', 'React.Respond.Support.Register')
# ('STEV', ' I think the clown or the ninja would be good.', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' Well would you wanna be clown or ninja instead of the Tick ?', 'React.Rejoinder.Re-challenge')
# ('SHER', ' Or...?', 'React.Rejoinder.Track.Clarify')
# ('STEV', ' I wanna be the Tick.', 'React.Respond.Response.Resolve.')
# ('SHER', ' Okay.', 'React.Respond.Support.Register')
# ('SHER', " I think the Tick's pretty classy myself.", 'React.Respond.Develop.Enhance')
# ('SHER', ' I was telling everybody at work that you wanted to be the Tick for Halloween', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' and they thought that was cool cause everybody at work watches the Tick', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' and they like it too.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' I thought that was pretty funny myself.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', " That's.", 'React.Respond.Reply.Agree')
# ('STEV', " That's.", 'React.Respond.Develop.Enhance')
# ('STEV', " That's really amuses me because", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' you know', 'Sustain.Continue.Monitor')
# ('STEV', " did they think he's really dumb ?", 'React.Rejoinder.Track.Confirm')
# ('SHER', " No, they think he's very funny.", 'React.Respond.Reply.Disawow')
# ('STEV', ' I know', 'React.Respond.Reply.Acknowledge')
# ('STEV', " that's why", 'Sustain.Continue.Prolong.Enhance')
# ('STEV', " cause he's so dumb that he's funny.", 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', " Yeah, he's kind of Showoff.", 'React.Respond.Develop.Enhance')
# ('SHER', ' Yeah, he is', 'React.Respond.Develop.Enhance')
# ('SHER', ' I guess.', 'React.Respond.Reply.Agree')
# ('STEV', " Arthur's better than him.", 'React.Respond.Develop.Enhance')
# ('SHER', ' Hunh.', 'React.Respond.Support.Register')
# ('STEV', ' At least Arthur has brains.', 'React.Respond.Develop.Extend')
# ('SHER', ' Aw.', 'React.Respond.Support.Register')
# ('STEV', ' What?', 'React.Rejoinder.Track.Clarify')
# ('SHER', " Arthur's the moth.", 'React.Rejoinder.Response.Resolve')
# ('SHER', ' Right ?', 'React.Rejoinder.Track.Confirm')
# ('SHER', " He's the...", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Um', 'React.Respond.Support.Register')
# ('STEV', ' they um call him the funny rabbit.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' A bunny rabbit ?', 'React.Rejoinder.Track.Probe')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Does he look like bunny rabbit ?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' Yeah', 'React.Respond.Reply.Affirm')
# ('STEV', ' and his little long ear things.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', " But I mean he's supposed to be moth in real life.", 'React.Respond.Develop.Elaborate')
# ('SHER', ' right ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' yeah.', 'React.Respond.Reply.Affirm')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Agree')
# ('SHER', ' Aw man', 'React.Respond.Support.Register')
# ('SHER', ' we gotta get rid of some of this stuff', 'Sustain.Continue.Prolong.Extend')
# ('SHER', " I've got more stuff in here than sense.", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Okay', 'React.Respond.Support.Register')
# ('SHER', ' Okay.', 'React.Respond.Support.Register')
# ('SHER', ' Oy yeah.', 'React.Respond.Support.Register')
# ('SHER', ' Now where are we at?', 'React.Rejoinder.Track.Clarify')
# ('SHER', " I still haven't found the sauce.", 'Open.Give.Fact.')
# ('SHER', ' Okay.', 'React.Respond.Support.Register')
# ('SHER', ' Oh I gotta take some Tylenol.', 'Open.Give.Fact.')
# ('STEV', ' Yack Pack two.', 'React.Respond.Develop.Elaborate')
# ('STEV', ' with playback and record', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' speed adjustment point six.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Mhm ?', 'React.Rejoinder.Track.Check')
# ('STEV', ' second memory.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' Batteries included', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' ages seven up.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Hm.', 'React.Respond.Support.Register')
# ('SHER', ' Really?', 'React.Rejoinder.Track.Confirm')
# ('STEV', " It's from Yess Entertainment.", 'React.Respond.Reply.Affirm')
# ('SHER', " And you think that's what Robbie would like for his birthday more than anything?", 'React.Rejoinder.Re-challenge')
# ('SHER', ' Hunh ?', 'React.Rejoinder.Track.Check')
# ('STEV', " I'd say so.", 'React.Respond.Response.Resolve.')
# ('SHER', ' Okay', 'React.Respond.Support.Register')
# ('SHER', " Well then that's what we'll get him if that's what you think.", 'React.Respond.Develop.Extend')
# ('SHER', " I think that's nice that they invited you to his birthday.", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' He did.', 'React.Respond.Develop.Extend')
# ('SHER', " Yeah I'm glad you guys got to be friends.", 'React.Respond.Develop.Enhance')
# ('SHER', ' Where in the heck did I put that?', 'React.Rejoinder.Track.Clarify')
# ('SHER', ' that pizza sauce.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' Pizza sauce ?', 'React.Rejoinder.Track.Probe')
# ('STEV', ' Maybe I put it in the fridge.', 'React.Rejoinder.Re-challenge')
# ('SHER', " Oh do you think you might've ?", 'React.Rejoinder.Track.Confirm')
# ('SHER', " Cause I can't find it any place.", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', " It's driving me crazy.", 'Open.Give.Fact.')
# ('STEV', ' Okay.', 'React.Respond.Support.Register')
# ('STEV', ' because some of  them  I put  them  over here.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', " What's here?", 'React.Rejoinder.Track.Clarify')
# ('STEV', ' You mean this ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Pizza sauce ?', 'React.Rejoinder.Track.Probe')
# ('SHER', " Yep, that's exactly what I was looking for.", 'Open.Give.Fact.')
# ('STEV', ' It was right here.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Thank you babe.', 'Open.Give.Fact.')
# ('STEV', " Maybe you're getting blind", 'React.Respond.Develop.Extend')
# ('STEV', " Well at least you're my mom.", 'React.Respond.Develop.Enhance')
# ('SHER', ' Hm yeah .', 'React.Respond.Support.Register')
# ('STEV', ' Mom why is the green ball out there ?', 'Open.Demand.Fact.')
# ('STEV', ' Did anyone play croquet or ?', 'React.Rejoinder.Re-challenge')
# ('SHER', " You know that ball's been sitting out there forever.", 'Sustain.Continue.Prolong.Elaborate')
# ('STEV', " We're also missing black one.", 'React.Respond.Develop.Extend')
# ('STEV', " But that wasn't Robbie's fault.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Alright.', 'React.Respond.Support.Register')
# ('SHER', ' One pepperoni pizza coming up.', 'Open.Give.Fact.')
# ('SHER', ' Kid.', 'React.Respond.Support.Register')
# ('STEV', ' Thank you,Mom.', 'Open.Give.Fact.')
# ('SHER', " You're welcome.", 'React.Respond.Develop.Enhance')
# ('STEV', ' Hey Mom.', 'React.Respond.Reply.Agree')
# ('SHER', ' Hey what?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' guess what they had on movie back there', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' um', 'React.Respond.Support.Register')
# ('STEV', " at um Albertson's.", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' I give up', 'React.Respond.Develop.Extend')
# ('SHER', " what'd they have?", 'React.Rejoinder.Track.Clarify')
# ('STEV', " I'll give you hint.", 'Sustain.Continue.Prolong.Elaborate')
# ('STEV', " It's the guy who wrote it was the same person who wrote The Secret Garden", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Give up ?', 'React.Rejoinder.Track.Confirm')
# ('SHER', ' Mhm.', 'React.Respond.Reply.Affirm')
# ('STEV', ' A Little Princess.', 'React.Respond.Develop.Extend')
# ('SHER', " Oh, that's right.", 'React.Respond.Reply.Agree')
# ('STEV', " It's also on video on here in Toys 'R' Us.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Mhm ?', 'React.Rejoinder.Track.Check')
# ('SHER', " Now for some reason that didn't do real well at the movie theaters.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Did it?', 'React.Rejoinder.Track.Confirm')
# ('SHER', ' What in the hell is this?', 'React.Rejoinder.Track.Clarify')
# ('STEV', ' Hunh ?', 'React.Rejoinder.Track.Check')
# ('SHER', ' Oh.', 'React.Respond.Reply.Affirm')
# ('STEV', ' No Mom.', 'Rejoinder.Counter')
# ('STEV', ' It  did great.', 'React.Respond.Develop.Extend')
# ('SHER', ' In the movie theaters ?', 'React.Rejoinder.Track.Probe')
# ('SHER', ' It did ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Hunh.', 'React.Respond.Support.Register')
# ('SHER', " For some reason I was under the impression that it didn't.", 'React.Respond.Develop.Extend')
# ('SHER', " That it didn't do that well honey.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' But', 'React.Respond.Develop.Extend')
# ('SHER', ' I could be wrong.', 'React.Respond.Reply.Disawow')
# ('SHER', ' Oh man.', 'React.Respond.Support.Register')
# ('SHER', ' Hey Steven ?', 'React.Rejoinder.Re-challenge')
# ('SHER', ' Come on over here', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' I want you to grate this cheese for me.', 'Open.Give.Fact.')
# ('SHER', ' Okay ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' Salami too.', 'React.Respond.Response.Resolve.')
# ('SHER', ' You know what to do?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' hot salami ?', 'React.Rejoinder.Track.Probe')
# ('SHER', ' Do you know how to... you know how to do this ?', 'React.Rejoinder.Rebound')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('STEV', ' I just scrape it.', 'React.Respond.Develop.Extend')
# ('SHER', ' Okay.', 'React.Respond.Support.Register')
# ('SHER', ' So yeah.', 'React.Respond.Develop.Extend')
# ('SHER', " Don't get your knuckles all bloody though.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' You know you gotta be careful.', 'React.Respond.Develop.Elaborate')
# ('SHER', ' Okay.', 'React.Respond.Support.Register')
# ('SHER', " And I'm gonna take this pizza crust off the dish rack here so.", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' This kitchen is so small.', 'Open.Give.Fact.')
# ('STEV', ' Mm.', 'React.Respond.Support.Register')
# ('SHER', ' You know I kinda hope nobody shows up cause this place is such dirty mess.', 'Open.Give.Fact.')
# ('STEV', ' I hope they do too.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' I look like mess too.', 'React.Respond.Develop.Elaborate')
# ('SHER', ' Nah, you look great.', 'React.Respond.Develop.Extend')
# ('STEV', ' Slice.', 'React.Respond.Reply.Affirm')
# ('STEV', ' Slice.', 'React.Respond.Reply.Affirm')
# ('SHER', " I'm glad you were good for Jack and Joanne too when they drove you over.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' That was nice of  them  to do.', 'React.Respond.Develop.Enhance')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Was it hard sitting in the back of their truck?', 'React.Rejoinder.Track.Clarify')
# ('SHER', ' They gotta pretty small truck', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' hunh.', 'React.Respond.Support.Register')
# ('STEV', ' Well, Shred said I wanna sit back there.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' And you know Missus um Taylor said.', 'Sustain.Continue.Monitor')
# ('STEV', ' No Shred', 'Rejoinder.Counter')
# ('STEV', " there's no room .", 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' Unhunh ?', 'React.Rejoinder.Track.Check')
# ('STEV', ' There was only room for me and Zach.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' And we were on opposite sides from each other.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Ah.', 'React.Respond.Support.Register')
# ('SHER', ' So did they put Shred in the front seat between  them  ?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Yeah.', 'React.Respond.Reply.Agree')
# ('STEV', ' Poor Shred .', 'Open.Attend')
# ('STEV', ' And guess what?', 'Sustain.Continue.Monitor')
# ('SHER', ' What?', 'React.Rejoinder.Track.Clarify')
# ('STEV', ' Shred chased um ground squirrel?', 'React.Rejoinder.Track.Probe')
# ('SHER', ' He did.', 'React.Respond.Reply.Disagree')
# ('SHER', ' Did he catch him ?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' No.', 'React.Respond.Reply.Disagree')
# ('SHER', ' Hm.', 'React.Respond.Support.Register')
# ('STEV', ' Zach.', 'React.Respond.Develop.Extend')
# ('STEV', ' Zach caught one.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' Except it bit him.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Uhoh.', 'React.Respond.Support.Register')
# ('SHER', ' Hope he has rabies shots.', 'React.Respond.Develop.Enhance')
# ('SHER', ' How was their soccer game?', 'React.Rejoinder.Track.Clarify')
# ('SHER', ' Did they win their soccer game ?', 'React.Rejoinder.Re-challenge')
# ('SHER', ' Or?', 'React.Rejoinder.Track.Confirm')
# ('STEV', " I didn't ask.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Oh.', 'React.Respond.Support.Register')
# ('STEV', ' He someone said', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' hi Steve.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Mhm ?', 'React.Rejoinder.Track.Check')
# ('STEV', ' That was probably Shred on the corner', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' I said I looked around and I shrugged.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Probably the wind I thought.', 'React.Respond.Develop.Extend')
# ('SHER', ' Ah.', 'React.Respond.Support.Register')
# ('STEV', ' It was actually Shred saying', 'Sustain.Continue.Prolong.Elaborate')
# ('STEV', ' hi Steve.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Mhm.', 'React.Respond.Support.Register')
# ('SHER', ' Is your grandmother feeling better ?', 'Open.Demand.Fact.')
# ('STEV', ' Yeah', 'React.Respond.Reply.Affirm')
# ('STEV', ' she wanted to go home and sleep afterward.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Yeah.', 'React.Respond.Support.Register')
# ('SHER', " Well she's supposed to go to the Dixie Land Jazz Festival this weekend.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' One of the venues or something so.', 'React.Respond.Develop.Extend')
# ('STEV', ' She did yesterday and.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('STEV', ' me and Grandpa had hard time trying to track her down.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' She told Grandpa to get me and bring me over there.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' And then we could not find  her .', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Unhunh ?', 'React.Rejoinder.Track.Check')
# ('SHER', ' Oh.', 'React.Respond.Support.Register')
# ('SHER', " Well that's usually pretty crowded and busy over there.", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('STEV', ' Down to two cheeses Mom.', 'React.Respond.Develop.Extend')
# ('SHER', ' Okay.', 'React.Respond.Reply.Agree')
# ('SHER', ' So did your dad take Mary Ann with him to San Francisco?', 'React.Rejoinder.Re-challenge')
# ('SHER', ' or did he just go by himself?', 'React.Rejoinder.Re-challenge')
# ('STEV', " I don't know.", 'React.Respond.Reply.Disawow')
# ('SHER', " You don't know ?", 'React.Rejoinder.Track.Confirm')
# ('STEV', " I didn't ask him about that.", 'Sustain.Continue.Prolong.Extend')
# ('STEV', " I don't.", 'React.Respond.Reply.Disawow')
# ('STEV', " I don't know why he even he even went there.", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' He did not tell me.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Mhm', 'React.Respond.Support.Register')
# ('SHER', ' I think he just wanted to get out of the Valley for while and have break.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Hunh ?', 'React.Rejoinder.Track.Check')
# ('SHER', ' I said I think he just wanted to.', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' I think he just wanted to get out of the Valley for while', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' I think he just needed break.', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', " He hasn't really had vacation.", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' He has with Mary Ann.', 'React.Respond.Develop.Elaborate')
# ('SHER', ' Oh did they go on vacation ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', ' One time yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Yeah.', 'React.Respond.Support.Register')
# ('STEV', ' You see Mom', 'React.Respond.Develop.Extend')
# ('STEV', ' does that look good ?', 'React.Rejoinder.Track.Confirm')
# ('SHER', ' Yeah', 'React.Respond.Reply.Affirm')
# ('SHER', ' I think so.', 'React.Respond.Reply.Disawow')
# ('STEV', ' Some of  them  I went through right here.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('SHER', " Well that's fine.", 'React.Respond.Develop.Enhance')
# ('SHER', ' you know what', 'Sustain.Continue.Monitor')
# ('SHER', " let's open that box of", 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' or that package of pastrami', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' not pastrami', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' pepperoni.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', ' Let me put these on there.', 'React.Respond.Develop.Enhance')
# ('SHER', ' You wanna put the.', 'Sustain.Continue.Monitor')
# ('SHER', ' You want the pepperoni under the cheese or the pepperoni on top of the cheese?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' On top of the cheese.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Okay', 'React.Respond.Support.Register')
# ('SHER', ' so,yeah, sprinkle the cheese around.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', " That's good idea.", 'React.Respond.Develop.Enhance')
# ('STEV', ' Hot salami hot salami hey hot salami for you Salami hot salami hey hot salami for you.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', " Mm, eat it up while it's still sizzling'", 'Open.Give.Fact.')
# ('STEV', ' Bugs Bunny used to sing that.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Yeah I remember that from the Bugs Bunny show.', 'React.Respond.Develop.Elaborate')
# ('SHER', ' Hunh.', 'React.Respond.Support.Register')
# ('STEV', ' That one that I rented', 'React.Respond.Develop.Extend')
# ('STEV', ' I like those ones.', 'React.Respond.Develop.Elaborate')
# ('SHER', ' Yeah.', 'React.Respond.Reply.Affirm')
# ('STEV', ' Then my favoritest one was when it was the Daffy Duck one', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' Quackbusters ?', 'React.Rejoinder.Track.Probe')
# ('SHER', ' Mhm ?', 'React.Rejoinder.Track.Check')
# ('STEV', ' That was my favorite ', 'Sustain.Continue.Prolong.Extend')
# ('STEV', " Or  there's  one  where Bugs Bunny was talking to that vampire .", 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' you know?', 'Sustain.Continue.Monitor')
# ('SHER', ' Oh, where he was.', 'React.Respond.Reply.Agree')
# ('STEV', ' I used to crack up', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' where he would turn into the bat.', 'React.Respond.Develop.Enhance')
# ('STEV', ' well he said and then he would turn into the umpire.', 'Sustain.Continue.Prolong.Extend')
# ('STEV', ' he said he said.', 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' and', 'React.Respond.Develop.Extend')
# ('STEV', ' He umpire.', 'React.Respond.Reply.Affirm')
# ('STEV', ' he says I am vampire.', 'Sustain.Continue.Prolong.Enhance')
# ('STEV', " he says Well hocuspocus I'm an umpire.", 'Sustain.Continue.Prolong.Enhance')
# ('STEV', " He  said Well hocuspocus. I'm bat. I'm bat too. Abracadabra.", 'Sustain.Continue.Prolong.Enhance')
# ('STEV', " You wouldn't hit bat with glasses on, would you?", 'React.Rejoinder.Re-challenge')
# ('STEV', ' Whack.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Silly.', 'React.Respond.Develop.Enhance')
# ('SHER', ' Do you want more cheese than this?', 'React.Rejoinder.Re-challenge')
# ('STEV', ' Mm.', 'React.Respond.Reply.Affirm')
# ('SHER', ' Does that look like enough ?', 'React.Rejoinder.Track.Confirm')
# ('STEV', " Let's put little bit more.", 'Sustain.Continue.Prolong.Elaborate')
# ('SHER', ' Let me cut some more off', 'React.Respond.Develop.Extend')
# ('SHER', ' Let me move these dishes into the sink.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Okay here, slide over', 'React.Respond.Develop.Extend')
# ('SHER', " this is really kind of tough kitchen to work in cause it's so teenytiny", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' and I have all my books and everything on this counter too and slice stuff', 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Okay.', 'React.Respond.Support.Register')
# ('SHER', " And I'll open up the pastrami.", 'Sustain.Continue.Prolong.Extend')
# ('SHER', ' Pepperoni', 'React.Respond.Support.Register')
# ('SHER', " I'm tired.", 'Open.Give.Fact.')
# ('STEV', ' hot salami.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', ' Boy.', 'React.Respond.Support.Register')
# ('STEV', ' You were gonna say hot salami?', 'React.Rejoinder.Track.Confirm')
# ('SHER', ' No, I was gonna say pastrami.', 'React.Respond.Reply.Disagree')
# ('SHER', ' Instead of pepperoni.', 'Sustain.Continue.Prolong.Enhance')
# ('SHER', " It's because I'm having dumb attack.", 'Sustain.Continue.Prolong.Elaborate')
# ('STEV', " No, you're having mom attack.", 'React.Respond.Develop.Enhance')
# ('SHER', ' Yeah I guess so.', 'React.Respond.Reply.Agree')
# ('STEV', ' You are entering the mom zone.', 'React.Respond.Develop.Enhance')
# ('SHER', ' Mom zone.', 'React.Respond.Develop.Enhance')
# ('SHER', " How's Robbie doing?", 'Open.Demand.Fact.')

# %% [markdown]
# # Questions

# %%
interrogative_words = ['whose', 'what', 'which', 'who', 'whom', 'what', 'which','why', 'where', 'when', 'how']

# %% [markdown]
# Detect all questions in phrases

# %%
with open('track_list') as track_list:
    track_list= track_list.readlines()
train_que =[]
train_tags=[]
for line in track_list:
    line = line.split('/')
    train_que.append(line[0])
    train_tags.append(line[1][:-1])

# %%
train_em_que = get_embeddings(train_que)

# %%
lr2 = LogisticRegression(C=0.01, class_weight='balanced')
lr2.fit(train_em_que,train_tags)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# LogisticRegression(C=0.01, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
true_tracks = {'1':'Track.Check', '2':'Track.Confirm', '3':'Track.Clarify','4':'Track.Probe'}

# %%
def map_tracks(tags_for_track, true_tags):
    for i in range(len(list(tags_for_track))):
        if tags_for_track[i]=='5':
            tag=tags_for_track[i]
        else:
            tag=true_tracks[tags_for_track[i]]
    return tag

# %%
def get_label_for_question(phrase,y_pred,current_speaker, previous_speaker, true_tracks, model,interrogative_words):
    questions=[]
    questions.append(phrase)
    question_embeddings = get_embeddings(questions)
    y_pred_track = lr2.predict(question_embeddings)
    tag_for_track=map_tracks(y_pred_track,true_tracks)
    if current_speaker!=previous_speaker:
        if y_pred=='React.Respond.' and tag_for_track!='5':
            y_pred='React.Rejoinder.'+tag_for_track
        if y_pred=='React.Rejoinder.' and tag_for_track!='5':
            y_pred+=tag_for_track
        if y_pred=='React.Rejoinder.' and tag_for_track=='5':
            for word in interrogative_words:
                if word in phrase:
                    y_pred='React.Rejoinder.Rebound'
                else:
                    y_pred='React.Rejoinder.Re-challenge'
        if y_pred=='Sustain.Continue.':
            y_pred='React.Rejoinder.'+tag_for_track
        if y_pred=='Open.':
            pass
    if current_speaker==previous_speaker:
        if  y_pred=='React.Rejoinder.' and tag_for_track!='5':
            y_pred+=tag_for_track
        if y_pred=='React.Rejoinder.' and tag_for_track=='5':
            for word in interrogative_words:
                if word in phrase:
                    y_pred='React.Rejoinder.Rebound'
                else:
                    y_pred='React.Rejoinder.Re-challenge'
        if y_pred=='Open.':
            pass
        if y_pred=='Sustain.Continue.':
            y_pred='Sustain.Continue.Monitor'
    return y_pred

# %%
print(get_label_for_question('What was it called?','React.Rejoinder.','SHER', 'SHAN',true_tracks,lr2, interrogative_words))
# Out:
# React.Rejoinder.Track.Clarify

# %% [markdown]
# # Sustain

# %%
# for sustain
def check_develop(phrase,previous_phrase,y_pred, y_pred_previous,current_speaker, previous_speaker):
    if current_speaker!=previous_speaker:
        if 'Sustain.Continue.' in y_pred_previous:
            if 'Sustain.Continue.' in y_pred:
                y_pred='React.Respond.Develop.'
    return y_pred

# %%
# for every line
def check_sustain(phrase,y_pred,y_pred_previous,current_speaker, previous_speaker):
    if current_speaker==previous_speaker:
        if y_pred_previous=='Sustain.Continue.':
             if y_pred!='Open.':
                y_pred='Sustain.Continue.'
    return y_pred

# %%
# if y_pred[i]=='Sustain.Continue.' or y_pred[i]=='React.Respond.Develop.':
def get_label_for_sustains(phrase, y_pred, sus_model):
    test_sustains=[]
    test_sustains.append(phrase)
    test_sustains_emb=get_embeddings(test_sustains)
    tags_for_sus=sus_model.predict(test_sustains_emb)
    if y_pred=='Sustain.Continue.':
        y_pred=''.join(tags_for_sus)
    if y_pred=='React.Respond.Develop.':
        cut_tags=''.join(tags_for_sus).split('.')[-1]
        if cut_tags!='Monitor':
            y_pred+=cut_tags
    return y_pred

# %%
test_sustains=[]
for i in range(len(phrases)):
    if y_pred[i]=='Sustain.Continue.' or y_pred[i]=='React.Respond.Develop.':
        test_sustains.append(phrases[i])

# %%
train_sustains=get_embeddings(sustains)

# %%
test_sustains_emb=get_embeddings(test_sustains)

# %%
lr_sus = LogisticRegression(C=0.01, class_weight='balanced')
lr_sus.fit(train_sustains,sus_tags)
tags_for_sus= lr_sus.predict(test_sustains_emb)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %% [markdown]
# # Replies

# %%
def get_label_for_responds(phrase,previous_phrase, y_pred,y_pred_previous,current_speaker,previous_speaker, model1, model2):
    try_replies=[]
    test_prev_lines = []
    test_responds=[]
    test_responds_prev_lines = []
    if '?' in previous_phrase:
        if current_speaker!=previous_speaker:
            test_prev_lines.append(previous_phrase)
            try_replies.append(phrase)
            test_concat = np.concatenate([get_embeddings(try_replies),get_embeddings(test_prev_lines)],axis=1)
            tag_for_reply = model1.predict(test_concat)
            y_pred=y_pred+''.join(tag_for_reply)
            if 'yes' in str(try_replies).lower():
                if y_pred=='React.Respond.Reply.Disagree':
                    if 'Confirm' in y_pred_previous:
                        y_pred='React.Respond.Reply.Affirm'
        else:
            test_responds_prev_lines.append(previous_phrase)
            test_responds.append(phrase)
            test_responds_concatenate = np.concatenate([get_embeddings(test_responds),get_embeddings(test_responds_prev_lines)], axis=1)
            tags_for_responds = model2.predict(test_responds_concatenate)
            y_pred=y_pred+''.join(tags_for_responds)
            if ' no ' in str(test_responds).lower():
                y_pred='Rejoinder.Counter'
                
    else:
        test_responds_prev_lines.append(previous_phrase)
        test_responds.append(phrase)
        test_responds_concatenate = np.concatenate([get_embeddings(test_responds),get_embeddings(test_responds_prev_lines)], axis=1)
        tags_for_responds = model2.predict(test_responds_concatenate)
        y_pred=y_pred+''.join(tags_for_responds)
        if ' no ' in str(test_responds).lower():
            y_pred='Rejoinder.Counter'
    return y_pred

# %%
print(get_label_for_responds('Oh there they are.','Where?', 'React.Respond.','React.Rejoinder.' ,'1','1', lr_reply, lr_responds))
# Out:
# React.Respond.Reply.Affirm

# %%
train_embed_replies=get_embeddings(replies)

# %%
train_prev_lines=get_embeddings(previous_lines)

# %%
reply_concatenate = np.concatenate([train_embed_replies,train_prev_lines], axis=1)

# %%
from sklearn.linear_model import LogisticRegression 
lr_reply = LogisticRegression(C=0.01, class_weight='balanced')
lr_reply.fit(reply_concatenate,tags)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
train_emb_responds=get_embeddings(responds)

# %%
train_prev_responds=get_embeddings(previous_responds)

# %%
responds_concatenate = np.concatenate([train_emb_responds,train_prev_responds], axis=1)

# %%
lr_responds = LogisticRegression(C=0.5, class_weight='balanced')
lr_responds.fit(responds_concatenate,respond_tags)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %% [markdown]
# # Rejoinder

# %%
def get_labels_for_rejoinder(phrase,y_pred,y_pred_previous,previous_phrase, current_speaker, previous_speaker):
    if ' no ' in phrase.lower():
            y_pred='React.Rejoinder.Counter'
    if '?' in previous_phrase:
        if previous_speaker!=current_speaker:
            y_pred='React.Rejoinder.Response.Resolve'
        else:
            y_pred='React.Rejoinder.Re-challenge'
    else:
        y_pred='React.Respond.Develop.Extend'
    return y_pred

# %% [markdown]
# # Open

# %%
def load_pickle(filepath):
    documents_f = open(filepath, 'rb')
    file = pickle.load(documents_f)
    documents_f.close() 
    return file

def divide_into_sentences(document):
    return [sent for sent in document.sents]

# %%
def number_of_fine_grained_pos_tags(sent):
    tag_dict = {'-LRB-': 0, '-RRB-': 0, ',': 0, ':': 0, '.': 0, "''": 0, '""': 0, '#': 0, 
    '``': 0, '$': 0, 'ADD': 0, 'AFX': 0, 'BES': 0, 'CC': 0, 'CD': 0, 'DT': 0,
    'EX': 0, 'FW': 0, 'GW': 0, 'HVS': 0, 'HYPH': 0, 'IN': 0, 'JJ': 0, 'JJR': 0, 
    'JJS': 0, 'LS': 0, 'MD': 0, 'NFP': 0, 'NIL': 0, 'NN': 0, 'NNP': 0, 'NNPS': 0, 
    'NNS': 0, 'PDT': 0, 'POS': 0, 'PRP': 0, 'PRP$': 0, 'RB': 0, 'RBR': 0, 'RBS': 0, 
    'RP': 0, '_SP': 0, 'SYM': 0, 'TO': 0, 'UH': 0, 'VB': 0, 'VBD': 0, 'VBG': 0, 
    'VBN': 0, 'VBP': 0, 'VBZ': 0, 'WDT': 0, 'WP': 0, 'WP$': 0, 'WRB': 0, 'XX': 0,
    'OOV': 0, 'TRAILING_SPACE': 0}
    for token in sent:
        if token.is_oov:
            tag_dict['OOV']+= 1
        elif token.tag_ == '':
            tag_dict['TRAILING_SPACE']+= 1
        else:
            tag_dict[token.tag_]+= 1
            
    return tag_dict

# %%
def number_of_dependency_tags(sent):
    dep_dict = {'acl': 0, 'advcl': 0, 'advmod': 0, 'amod': 0, 'appos': 0, 'aux': 0, 'case': 0,
    'cc': 0, 'ccomp': 0, 'clf': 0, 'compound': 0, 'conj': 0, 'cop': 0, 'csubj': 0,
    'dep': 0, 'det': 0, 'discourse': 0, 'dislocated': 0, 'expl': 0, 'fixed': 0,
    'flat': 0, 'goeswith': 0, 'iobj': 0, 'list': 0, 'mark': 0, 'nmod': 0, 'nsubj': 0,
    'nummod': 0, 'obj': 0, 'obl': 0, 'orphan': 0, 'parataxis': 0, 'prep': 0, 'punct': 0,
    'pobj': 0, 'dobj': 0, 'attr': 0, 'relcl': 0, 'quantmod': 0, 'nsubjpass': 0,
    'reparandum': 0, 'ROOT': 0, 'vocative': 0, 'xcomp': 0, 'auxpass': 0, 'agent': 0,
    'poss': 0, 'pcomp': 0, 'npadvmod': 0, 'predet': 0, 'neg': 0, 'prt': 0, 'dative': 0,
    'oprd': 0, 'preconj': 0, 'acomp': 0, 'csubjpass': 0, 'meta': 0, 'intj': 0, 
    'TRAILING_DEP': 0}
    
    for token in sent:
        if token.dep_== '':
            dep_dict['TRAILING_DEP']+= 1
        else:
            try:
                dep_dict[token.dep_]+= 1
            except:
                print('Unknown dependency for token: "' + token.orth_ +'". Passing.')
        
    return dep_dict

# %%
def number_of_specific_entities(sent):
    entity_dict = {
    'PERSON': 0, 'NORP': 0, 'FAC': 0, 'ORG': 0, 'GPE': 0, 'LOC': 0,
    'PRODUCT': 0, 'EVENT': 0, 'WORK_OF_ART': 0, 'LAW': 0, 'LANGUAGE': 0,
    'DATE': 0, 'TIME': 0, 'PERCENT': 0, 'MONEY': 0, 'QUANTITY': 0,
    'ORDINAL': 0, 'CARDINAL': 0 }    
    entities = [ent.label_ for ent in sent.as_doc().ents]
    for entity in entities:
        entity_dict[entity]+=1     
    return entity_dict

# %%
def predict(test_sent, classifier, scaler=None):
    parsed_test = divide_into_sentences(nlp(test_sent))
    # Get features
    sentence_with_features = {}
    entities_dict = number_of_specific_entities(parsed_test[0])
    sentence_with_features.update(entities_dict)
    pos_dict = number_of_fine_grained_pos_tags(parsed_test[0])
    sentence_with_features.update(pos_dict)
    #dep_dict = number_of_dependency_tags(parsed_test[0])
    #sentence_with_features.update(dep_dict)
    df = pd.DataFrame(sentence_with_features, index=[0])
    if scaler:
        df = scaler.transform(df)
    
    prediction = classifier.predict(df)
    if prediction == 0:
        open_tag='Fact'
    else:
        open_tag='Opinion'
    return open_tag

# %%
nn_classifier = load_pickle('nn_classifier.pickle')

# %%
scaler = load_pickle('scaler.pickle')

# %%
# if y_pred[i]=='Open.':
def get_open_labels(phrase,y_pred,nn_classifier,scaler):
    open_tag =predict(phrase,nn_classifier,scaler)
    if open_tag=='Fact':
        if '?' not in phrase:
            open_tag='Give.Fact.'
        else:
            open_tag='Demand.Fact.'
    else:
        if '?' not in phrase:
            open_tag='Give.Opinion.'
        else:
            open_tag='Demand.Opinion.'
    y_pred=y_pred+open_tag
    if len(word_tokenize(phrase))<4:
        poses=[]
        doc=nlp(phrase)
        for token in doc:
            poses.append(token.pos_)
        if 'PROPN' in poses:
            y_pred='Open.Attend'
    return y_pred
